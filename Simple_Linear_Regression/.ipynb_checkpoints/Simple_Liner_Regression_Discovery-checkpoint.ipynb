# %% [markdown]
# # 単回帰分析
#
# ## 分析の手順
# 1. 使用するデータセットを確認する
# 2. データセットを加工する
# 3. 回帰式を求めることに意義があるか確認する
# 4. 回帰式を求める
# 5. 回帰式の精度
# 6. 回帰係数の検定
# 7. 母回帰を推定する
# 8. 予測する
#
# ## 参考にする資料
# - マンガでわかる統計学「回帰分析編」 高橋信 オーム社
# - Pythonではじめる機械学習 オライリー・ジャパン
# - http://www.randpy.tokyo/entry/2017/06/26/153800#fn-6a2f787c
# - http://www.mwsoft.jp/programming/numpy/statsmodels_ols.html
#
# ---

# %% [markdown]
# ## １．使用するデータセットの確認
# 取得元：https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset
#
# ### 分析の目的
# **単一の説明変数から目的変数（サービス利用者数）を予測する**
#
# 想定できるビジネス上の課題・施策
# - 省略
#
# ### 公開されていた情報
# - アメリカのシェアサイクル（Capital Bikeshare）の履歴データ
# - 会員登録していなくても利用することができる
# - 天気情報は、http://www.freemeteo.com から取得している
# - 対象の期間は、2011-01-01〜2012-12-31
#
# ### 想定できるビジネス上の考慮点
# - サービス提供している地域でイベントがあると利用者の増加が見込まれる
# - おそらく乗り捨て式のため、機会損失や自転車の再配置に伴うコストが発生する
#
# ### データセットを目検して気づいたこと
# - 省略
#
# ---

# %%
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
data_day = pd.read_csv('Bike_Sharing_Data_day.csv')
data_day.head(3)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
#
#     cnt
# 0   985
# 1   801
# 2  1349

# %%
data_day.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
data_day['dteday'] = data_day.dteday.map(lambda x: datetime.strptime(x,'%Y-%m-%d'))
data_day.describe(include='all')
# Out:
#            instant               dteday      season          yr        mnth  \
# count   731.000000                  731  731.000000  731.000000  731.000000
# unique         NaN                  731         NaN         NaN         NaN
# top            NaN  2012-02-14 00:00:00         NaN         NaN         NaN
# freq           NaN                    1         NaN         NaN         NaN
# first          NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# last           NaN  2012-12-31 00:00:00         NaN         NaN         NaN
# mean    366.000000                  NaN    2.496580    0.500684    6.519836
# std     211.165812                  NaN    1.110807    0.500342    3.451913
# min       1.000000                  NaN    1.000000    0.000000    1.000000
# 25%     183.500000                  NaN    2.000000    0.000000    4.000000
# 50%     366.000000                  NaN    3.000000    1.000000    7.000000
# 75%     548.500000                  NaN    3.000000    1.000000   10.000000
# max     731.000000                  NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# first          NaN         NaN         NaN         NaN         NaN
# last           NaN         NaN         NaN         NaN         NaN
# mean      0.028728    2.997264    0.683995    1.395349    0.495385
# std       0.167155    2.004787    0.465233    0.544894    0.183051
# min       0.000000    0.000000    0.000000    1.000000    0.059130
# 25%       0.000000    1.000000    0.000000    1.000000    0.337083
# 50%       0.000000    3.000000    1.000000    1.000000    0.498333
# 75%       0.000000    5.000000    1.000000    2.000000    0.655417
# max       1.000000    6.000000    1.000000    3.000000    0.861667
#
#              atemp         hum   windspeed       casual   registered  \
# count   731.000000  731.000000  731.000000   731.000000   731.000000
# unique         NaN         NaN         NaN          NaN          NaN
# top            NaN         NaN         NaN          NaN          NaN
# freq           NaN         NaN         NaN          NaN          NaN
# first          NaN         NaN         NaN          NaN          NaN
# last           NaN         NaN         NaN          NaN          NaN
# mean      0.474354    0.627894    0.190486   848.176471  3656.172367
# std       0.162961    0.142429    0.077498   686.622488  1560.256377
# min       0.079070    0.000000    0.022392     2.000000    20.000000
# 25%       0.337842    0.520000    0.134950   315.500000  2497.000000
# 50%       0.486733    0.626667    0.180975   713.000000  3662.000000
# 75%       0.608602    0.730209    0.233214  1096.000000  4776.500000
# max       0.840896    0.972500    0.507463  3410.000000  6946.000000
#
#                 cnt
# count    731.000000
# unique          NaN
# top             NaN
# freq            NaN
# first           NaN
# last            NaN
# mean    4504.348837
# std     1937.211452
# min       22.000000
# 25%     3152.000000
# 50%     4548.000000
# 75%     5956.000000
# max     8714.000000

# %% [markdown]
# ### 気づいたこと
# - 省略
#
# ---

# %% [markdown]
# ## ２．データセットの加工

# %% [markdown]
# 予測難易度を下げるため、予め、好天候の日のみに絞る

# %%
# 晴れの日に限定し、単相関係数を確認したいカラムを抽出する
df = data_day[data_day['weathersit']==1]
df_coef = df[['temp','atemp','hum','windspeed','casual','registered','cnt']]

# %%
# 変数感の散布図と回帰直線を確認する
sns.pairplot(df_coef, kind = "reg")

# %%
# 総利用数との単相関係数を確認する
col_name = df_coef.columns.values
for i in range(len(col_name)-1):
    x = df_coef[col_name[i]]
    y = df_coef['cnt']
    rxy = np.corrcoef(x,y)
    print("単相関係数:{}".format(rxy[0][1]), " :{}".format(col_name[i]))
# Out:
# 単相関係数:0.6221904913438957  :temp
# 単相関係数:0.6235696560934256  :atemp
# 単相関係数:0.160751307645761  :hum
# 単相関係数:-0.1939408966961378  :windspeed
# 単相関係数:0.634990476344589  :casual
# 単相関係数:0.9356576444814501  :registered

# %% [markdown]
# 標準化された気温と体感温度はサービス利用者との弱い関係性が認められる
# **想像に難くない結果だが、会員登録済み利用者数は、全体のサービス利用者との関係性が非常に強い**
#
# ---

# %% [markdown]
# ## ３．回帰式を求めることに意義があるか確認する
#
# **回帰係数の検定を行いたいため、会員登録済み利用者から全体のサービス利用者を予測する回帰式を求める。**
# 会員登録済み利用者を事前に把握できるシステムではない（完全予約制ではない）ため、ビジネス的な意義はない。

# %%
lr_df = df[['registered','cnt']]
lr_df.head()
# Out:
#    registered   cnt
# 2        1229  1349
# 3        1454  1562
# 4        1518  1600
# 5        1518  1606
# 8         768   822

# %%
# 散布図を描画
plt.figure()

x = lr_df['registered']
y = lr_df['cnt']
plt.scatter(x, y, c='black')

plt.title("User(registered) - User(All)")
plt.xlabel("User(registered)")
plt.ylabel("User(All)")
plt.grid(True)

# %%
# 単相関係数
np.corrcoef(x,y)[0][1]
# Out:
# 0.93565764448145006

# %% [markdown]
# 事前に確認した通り
#
# ---

# %% [markdown]
# ## ４．回帰式を求める

# %%
x = lr_df.loc[:, ['registered']].as_matrix()
y = lr_df['cnt'].as_matrix()

lr = LinearRegression()
lr.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# 散布図
plt.scatter(x, y)
# 回帰直線
plt.plot(x, lr.predict(x), c='red')

# %%
print("回帰係数:{}".format(lr.coef_[0]))
print("切片　　:{}".format(lr.intercept_))
# Out:
# 回帰係数:1.146872337635713
# 切片　　:389.3546261449601

# %% [markdown]
# ---

# %% [markdown]
# ## ５．回帰式の精度

# %%
print("決定係数:{}".format(lr.score(x,y)))
# Out:
# 決定係数:0.8754552276765755

# %% [markdown]
# **決定係数が、1.0に近く精度は高い**
#
# ---

# %% [markdown]
# ## ６．回帰係数の検定

# %% [markdown]
# scikit-learnのメソッドではp値が算出されていないため、statsmodelsを使用する
# **有意水準は、0.05とする**

# %%
import statsmodels.api as smf

# %%
x = lr_df['registered']
y = lr_df['cnt']
model = smf.OLS(y, smf.add_constant(x))
result = model.fit()

# 回帰係数と切片を取得
a, b = result.params
# 散布図と回帰直線をプロット
plt.scatter(x, y)
plt.plot(x, a+b*x, color='red')
plt.show()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     3240.
# Date:                Sat, 21 Apr 2018   Prob (F-statistic):          1.18e-210
# Time:                        18:38:49   Log-Likelihood:                -3664.7
# No. Observations:                 463   AIC:                             7333.
# Df Residuals:                     461   BIC:                             7342.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        389.3546     84.655      4.599      0.000       222.997   555.712
# registered     1.1469      0.020     56.925      0.000         1.107     1.186
# ==============================================================================
# Omnibus:                      100.693   Durbin-Watson:                   1.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              166.329
# Skew:                           1.347   Prob(JB):                     7.62e-37
# Kurtosis:                       4.167   Cond. No.                     1.15e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **p値 ＜ 0.05 であることがわかった**
# 統計的に有意である
#
# ---

# %% [markdown]
# ## ７．母回帰を推定する
# ## ８．予測する

# %%
df = data_day[['temp','casual','weathersit']]
df = df[df['weathersit']==1]
df.head()
# Out:
#        temp  casual  weathersit
# 2  0.196364     120           1
# 3  0.200000     108           1
# 4  0.226957      82           1
# 5  0.204348      88           1
# 8  0.138333      54           1

# %%
df.describe(include='all')
# Out:
#              temp       casual  weathersit
# count  463.000000   463.000000       463.0
# mean     0.511541   964.030238         1.0
# std      0.191165   700.476488         0.0
# min      0.059130    15.000000         1.0
# 25%      0.338750   436.000000         1.0
# 50%      0.521667   829.000000         1.0
# 75%      0.692084  1247.500000         1.0
# max      0.861667  3410.000000         1.0

# %%
# 散布図を描画
plt.figure()

x = df['temp']
y = df['casual']
plt.scatter(x, y, c='black')

plt.title("Temperature - Casual User")
plt.xlabel("Temperature")
plt.ylabel("User(casual)")
plt.grid(True)

# %%
# 単相関係数を確認する
np.corrcoef(x,y)
# Out:
# array([[ 1.        ,  0.52347371],
#        [ 0.52347371,  1.        ]])

# %% [markdown]
# **やや弱いが、関連性がある**

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df.loc[:, ['temp']].as_matrix()
y = df['casual'].as_matrix()

lr = LinearRegression()
lr.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# 散布図
plt.scatter(x, y)
# 回帰直線
plt.plot(x, lr.predict(x), c='red')

# %%
print("回帰係数:{}".format(lr.coef_[0]))
print("切片　　:{}".format(lr.intercept_))
print("決定係数:{}".format(lr.score(x,y)))
# Out:
# 回帰係数:1918.140047964587
# 切片　　:-17.17792477927867
# 決定係数:0.27402472777630416

# %% [markdown]
# 単相関係数からも予測できたように、高い精度は得られなかった
#
# ---
